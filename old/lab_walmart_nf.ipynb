# %%
import pandas as pd
import matplotlib.pyplot as plt
from neuralforecast import NeuralForecast
from neuralforecast.models import TimeLLM, NHITS, PatchTST, LSTM
from transformers import GPT2Config, GPT2Model, GPT2Tokenizer
import os
from utilsforecast.plotting import plot_series
from neuralforecast.losses.pytorch import MQLoss
from utilsforecast.evaluation import evaluate
from utilsforecast.losses import rmse, mae, mape, mse

# %% [markdown]
# ### NHITS

# %%
Y_df = pd.read_csv("data/processed/walmart_sales/merged_nf_small.csv")
Y_df["ds"] = pd.to_datetime(Y_df["ds"])
Y_train_df = Y_df[Y_df["ds"] < "2012-01-01"]
Y_test_df = Y_df[Y_df["ds"] >= "2012-01-01"]

models = [
    NHITS(
        h=43,
        input_size=64,
        hist_exog_list=[
            "Type",
            "Size",
            "Year",
            "Month",
            "Week",
            "IsHoliday",
            "MarkDown1",
            "MarkDown2",
            "MarkDown3",
            "Fuel_Price",
        ],
        scaler_type="robust",
        max_steps=200,
    ),
]
nf = NeuralForecast(models=models, freq="W-FRI")

nf.fit(df=Y_train_df)
# Out:
# Seed set to 1
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | blocks       | ModuleList    | 3.2 M  | train
# -------------------------------------------------------
# 3.2 M     Trainable params
# 0         Non-trainable params
# 3.2 M     Total params
# 12.891    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_steps=200` reached.

# %%
fig, ax = plt.subplots(1, 1, figsize=(40, 10))

Y_hat_df = nf.predict().reset_index()

ax.plot(Y_df["ds"], Y_df["y"], label="Actual", color="blue", linewidth=2)
ax.plot(Y_hat_df["ds"], Y_hat_df["NHITS"], label="Forecast", color="red", linewidth=2)

forecast_start_date = Y_hat_df["ds"].min()
forecast_end_date = Y_hat_df["ds"].max()

ax.axvline(
    x=forecast_start_date,
    color="green",
    linestyle="--",
    linewidth=2,
    label="Forecast Start",
)
ax.axvline(
    x=forecast_end_date,
    color="green",
    linestyle="--",
    linewidth=2,
    label="Forecast End",
)

ax.set_title("Walmart Sales Forecast", fontsize=22)
ax.set_ylabel("Weekly Sales", fontsize=20)
ax.set_xlabel("Timestamp", fontsize=20)
ax.legend(prop={"size": 15})
ax.grid()
plt.show()
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %% [markdown]
# ### Cross-Validation

# %%
os.environ["NIXTLA_ID_AS_COL"] = "1"

# %%
Y_df = pd.read_csv("data/processed/walmart_sales/merged_nf_mid.csv")
Y_df["ds"] = pd.to_datetime(Y_df["ds"])

# %%
plot_series(Y_df)

# %%
horizon = 24

models = [
    NHITS(
        h=horizon,
        input_size=int(2.5 * horizon),
        loss=MQLoss(),
        hist_exog_list=[
            "Type",
            "Size",
            "Year",
            "Month",
            "Week",
            "IsHoliday",
            "MarkDown1",
            "MarkDown2",
            "MarkDown3",
            "Fuel_Price",
        ],
        scaler_type="robust",
    ),
    PatchTST(
        h=horizon,
        input_size=int(2.5 * horizon),
        loss=MQLoss(),
        scaler_type="robust",
    ),
    LSTM(
        h=horizon,
        input_size=int(2.5 * horizon),
        loss=MQLoss(),
        hist_exog_list=[
            "Type",
            "Size",
            "Year",
            "Month",
            "Week",
            "IsHoliday",
            "MarkDown1",
            "MarkDown2",
            "MarkDown3",
            "Fuel_Price",
        ],
        scaler_type="robust",
    ),
]

nf = NeuralForecast(models=models, freq="W-FRI")
# Out:
# Seed set to 1
# Seed set to 1
# Seed set to 1

# %%
cv_df = nf.cross_validation(Y_df, n_windows=3, step_size=horizon, refit=1)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MQLoss        | 5      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | blocks       | ModuleList    | 3.2 M  | train
# -------------------------------------------------------
# 3.2 M     Trainable params
# 5         Non-trainable params
# 3.2 M     Total params
# 12.965    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ...

# %%
cv_df.head()
# Out:
#   unique_id         ds     cutoff  NHITS-median  NHITS-lo-90  NHITS-lo-80  \
# 0    s31d26 2011-06-17 2011-06-10   8241.791016  8240.276367  8244.584961
# 1    s31d26 2011-06-24 2011-06-10   8338.878906  8317.507812  8338.232422
# 2    s31d26 2011-07-01 2011-06-10   8242.558594  8230.875000  8204.562500
# 3    s31d26 2011-07-08 2011-06-10   8302.148438  8242.215820  8262.814453
# 4    s31d26 2011-07-15 2011-06-10   8132.809570  8073.006836  8103.532227
#
#    NHITS-hi-80  NHITS-hi-90  PatchTST-median  PatchTST-lo-90  PatchTST-lo-80  \
# 0  8248.995117  8270.358398      8127.482422     8028.958496     8067.642090
# 1  8358.113281  8376.239258      7848.410645     7785.345703     7823.185547
# 2  8287.357422  8291.442383      7868.014160     7723.291504     7774.912109
# 3  8292.406250  8295.718750      7631.156738     7502.988281     7559.127930
# 4  8154.797852  8163.259766      7654.096680     7565.065430     7595.089355
#
# ...

# %%
evaluation_df = evaluate(cv_df.loc[:, cv_df.columns != "cutoff"], metrics=[mse])

# %%
evaluation_df["best_model"] = evaluation_df.drop(
    columns=["metric", "unique_id"]
).idxmin(axis=1)
evaluation_df
# Out:
#   unique_id metric  NHITS-median  PatchTST-median   LSTM-median   best_model
# 0    s31d26    mse  1.070331e+07     4.254735e+06  2.390403e+06  LSTM-median

# %%
summary_df = (
    evaluation_df.groupby(["metric", "best_model"]).size().sort_values().to_frame()
)
summary_df = summary_df.reset_index()
summary_df.columns = ["metric", "model", "num. of unique_ids"]
summary_df
# Out:
#   metric        model  num. of unique_ids
# 0    mse  LSTM-median                   1
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Time-LLM

# %%
Y_df = pd.read_csv("data/processed/walmart_sales/merged_nf_small.csv")
Y_df["ds"] = pd.to_datetime(Y_df["ds"])
Y_train_df = Y_df[Y_df["ds"] < "2012-01-01"]
Y_test_df = Y_df[Y_df["ds"] >= "2012-01-01"]

gpt2_config = GPT2Config.from_pretrained("openai-community/gpt2")
gpt2 = GPT2Model.from_pretrained("openai-community/gpt2", config=gpt2_config)
gpt2_tokenizer = GPT2Tokenizer.from_pretrained("openai-community/gpt2")

prompt_prefix = "This dataset is a time series containing weekly sales data for various Walmart stores. It exhibits yearly seasonality."

models = [
    TimeLLM(
        h=24,
        input_size=64,
        llm=gpt2,
        llm_config=gpt2_config,
        llm_tokenizer=gpt2_tokenizer,
        prompt_prefix=prompt_prefix,
        batch_size=12,
        windows_batch_size=12,
        scaler_type="robust",
        max_steps=100,
    ),
]

nf = NeuralForecast(models=models, freq="W-FRI")

nf.fit(df=Y_train_df)

# %%
fig, ax = plt.subplots(1, 1, figsize=(40, 10))

Y_hat_df = nf.predict().reset_index()

ax.plot(Y_df["ds"], Y_df["y"], label="Actual", color="blue", linewidth=2)
ax.plot(Y_hat_df["ds"], Y_hat_df["NHITS"], label="Forecast", color="red", linewidth=2)

forecast_start_date = Y_hat_df["ds"].min()
forecast_end_date = Y_hat_df["ds"].max()

ax.axvline(
    x=forecast_start_date,
    color="green",
    linestyle="--",
    linewidth=2,
    label="Forecast Start",
)
ax.axvline(
    x=forecast_end_date,
    color="green",
    linestyle="--",
    linewidth=2,
    label="Forecast End",
)

ax.set_title("Walmart Sales Forecast", fontsize=22)
ax.set_ylabel("Weekly Sales", fontsize=20)
ax.set_xlabel("Timestamp", fontsize=20)
ax.legend(prop={"size": 15})
ax.grid()
plt.show()
